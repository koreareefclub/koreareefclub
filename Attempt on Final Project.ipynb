# %%
import pandas as pd

# import diabetic data
df = pd.read_csv('/Users/Dawn/Documents/Python Scripts/diabetic_data.csv', header=0)

# %%
# show df
df
# Out:
#         encounter_id  patient_nbr             race  gender       age weight  \
# 0            2278392      8222157        Caucasian  Female    [0-10)      ?
# 1             149190     55629189        Caucasian  Female   [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3             500364     82442376        Caucasian    Male   [30-40)      ?
# 4              16680     42519267        Caucasian    Male   [40-50)      ?
# 5              35754     82637451        Caucasian    Male   [50-60)      ?
# 6              55842     84259809        Caucasian    Male   [60-70)      ?
# 7              63768    114882984        Caucasian    Male   [70-80)      ?
# 8              12522     48330783        Caucasian  Female   [80-90)      ?
# 9              15738     63555939        Caucasian  Female  [90-100)      ?
# 10             28236     89869032  AfricanAmerican  Female   [40-50)      ?
# ...

# %%
# print uniques
import numpy as np

print('encounter_id:', np.unique(df['encounter_id']))
print('encounter_id:', np.unique(df['race']))
# Out:
# encounter_id: [    12522     15738     16680 ..., 443854148 443857166 443867222]
# encounter_id: ['?' 'AfricanAmerican' 'Asian' 'Caucasian' 'Hispanic' 'Other']

# %%
df_edit
# Out:
#         encounter_id  patient_nbr  admission_type_id  \
# 0            2278392      8222157                  6
# 1             149190     55629189                  1
# 2              64410     86047875                  1
# 3             500364     82442376                  1
# 4              16680     42519267                  1
# 5              35754     82637451                  2
# 6              55842     84259809                  3
# 7              63768    114882984                  1
# 8              12522     48330783                  2
# 9              15738     63555939                  3
# 10             28236     89869032                  1
# 11             36900     77391171                  2
# 12             40926     85504905                  1
# 13             42570     77586282                  1
# 14             62256     49726791                  3
# 15             73578     86328819                  1
# 16             77076     92519352                  1
# ...

# %%
df
# Out:
#         encounter_id  patient_nbr             race  gender       age weight  \
# 0            2278392      8222157        Caucasian  Female    [0-10)      ?
# 1             149190     55629189        Caucasian  Female   [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3             500364     82442376        Caucasian    Male   [30-40)      ?
# 4              16680     42519267        Caucasian    Male   [40-50)      ?
# 5              35754     82637451        Caucasian    Male   [50-60)      ?
# 6              55842     84259809        Caucasian    Male   [60-70)      ?
# 7              63768    114882984        Caucasian    Male   [70-80)      ?
# 8              12522     48330783        Caucasian  Female   [80-90)      ?
# 9              15738     63555939        Caucasian  Female  [90-100)      ?
# 10             28236     89869032  AfricanAmerican  Female   [40-50)      ?
# ...
